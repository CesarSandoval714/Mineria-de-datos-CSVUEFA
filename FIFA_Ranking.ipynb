# %% [markdown]
# <a href="https://colab.research.google.com/github/CesarSandoval714/Mineria-de-datos-CSVUEFA/blob/main/FIFA_Ranking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cesar Jaziel Sandoval Mata
# 1. Adquisición de datos

# %%
import requests
import io
import numpy as np
from math import sqrt
import random as rd
from bs4 import BeautifulSoup
import pandas as pd
from tabulate import tabulate
from typing import Tuple, List
from scipy import stats
import re
from datetime import datetime
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
import seaborn as sns
from sklearn.cluster import KMeans



def get_soup(url: str) -> BeautifulSoup:
    response = requests.get(url)
    return BeautifulSoup(response.content, 'html.parser')

def get_csv_from_url(url:str) -> pd.DataFrame:
    s=requests.get(url).content
    return pd.read_csv(io.StringIO(s.decode('utf-8')))

def print_tabulate(df: pd.DataFrame):
    print(tabulate(df, headers=df.columns, tablefmt='orgtbl'))


df = get_csv_from_url("https://raw.githubusercontent.com/CesarSandoval714/Mineria-de-datos-CSVUEFA/main/FIFA%20PLAYERS%20RATINGS.csv")
df.head(500)
# Out:
#          id           name                       full_name  birth_date  age  \
# 0    158023       L. Messi  Lionel Andrés Messi Cuccittini  24/06/1987   31
# 1    190460     C. Eriksen    Christian  Dannemann Eriksen  14/02/1992   27
# 2    195864       P. Pogba                      Paul Pogba  15/03/1993   25
# 3    198219     L. Insigne                 Lorenzo Insigne  04/06/1991   27
# 4    201024   K. Koulibaly               Kalidou Koulibaly  20/06/1991   27
# ..      ...            ...                             ...         ...  ...
# 495  201818        A. Musa                      Ahmed Musa  14/10/1992   26
# 496  206424    M. Morozyuk                 Mykola Morozyuk  17/01/1988   31
# 497  192087  G. Schennikov              Georgiy Schennikov  27/04/1991   27
# 498  210007  André Ramalho             André Ramalho Silva  16/02/1992   27
# 499  208509       T. Foket                    Thomas Foket  25/09/1994   24
#
# ...

# %% [markdown]
# 2. Limpieza de datos

# %%
df.shape
# Out:
# (17954, 92)

# %%
df.isna().sum()
# Out:
# id               0
# name             0
# full_name        0
# birth_date       0
# age              0
#               ...
# LB            2065
# LCB           2065
# CB            2065
# RCB           2065
# RB            2065
# Length: 92, dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (156, 92)
