# %% [markdown]
# <a href="https://colab.research.google.com/github/CesarSandoval714/Mineria-de-datos-CSVUEFA/blob/main/FIFA_players_Ranking_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cesar Jaziel Sandoval Mata
#
# 1.Adquisición de datos

# %%
import requests
import io
import numpy as np
from math import sqrt
import random as rd
from bs4 import BeautifulSoup
import pandas as pd
from tabulate import tabulate
from typing import Tuple, List
from scipy import stats
import re
from datetime import datetime
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
import seaborn as sns
from sklearn.cluster import KMeans



def get_soup(url: str) -> BeautifulSoup:
    response = requests.get(url)
    return BeautifulSoup(response.content, 'html.parser')

def get_csv_from_url(url:str) -> pd.DataFrame:
    s=requests.get(url).content
    return pd.read_csv(io.StringIO(s.decode('utf-8')))

def print_tabulate(df: pd.DataFrame):
    print(tabulate(df, headers=df.columns, tablefmt='orgtbl'))


df = get_csv_from_url("https://raw.githubusercontent.com/CesarSandoval714/Mineria-de-datos-CSVUEFA/main/FIFA%20PLAYERS%20RATINGS.csv")
df.head(1000)
# Out:
#          id             name                       full_name  birth_date  age  \
# 0    158023         L. Messi  Lionel Andrés Messi Cuccittini  24/06/1987   31
# 1    190460       C. Eriksen    Christian  Dannemann Eriksen  14/02/1992   27
# 2    195864         P. Pogba                      Paul Pogba  15/03/1993   25
# 3    198219       L. Insigne                 Lorenzo Insigne  04/06/1991   27
# 4    201024     K. Koulibaly               Kalidou Koulibaly  20/06/1991   27
# ..      ...              ...                             ...         ...  ...
# 995  164478         C. Obasi            Chinedu Obasi Ogbuke  01/06/1986   32
# 996   16254        T. Howard                      Tim Howard  06/03/1979   40
# 997  168317        H. Goitom                    Henok Goitom  22/09/1984   34
# 998  220029        S. Khaoui              Saîf-Eddine Khaoui  27/04/1995   23
# 999  188540  R. van La Parra              Rajiv van La Parra  04/06/1991   27
#
#      height_cm  weight_kgs  positions    nationality  overall_rating  ...  \
# 0       170.18        72.1   CF,RW,ST      Argentina              94  ...
# 1       154.94        76.2  CAM,RM,CM        Denmark              88  ...
# 2       190.50        83.9     CM,CAM         France              88  ...
# 3       162.56        59.0      LW,ST          Italy              88  ...
# 4       187.96        88.9         CB        Senegal              88  ...
# ..         ...         ...        ...            ...             ...  ...
# 995     187.96        78.9         ST        Nigeria              72  ...
# 996     190.50        88.0         GK  United States              72  ...
# 997     187.96        84.8         ST        Eritrea              72  ...
# 998     182.88        68.0  CAM,RM,CM        Tunisia              72  ...
# 999     154.94        72.1      LM,LW    Netherlands              72  ...
#
#       LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB
# 0    64+2  61+2  61+2  61+2  64+2  59+2  48+2  48+2  48+2  59+2
# 1    71+3  71+3  71+3  71+3  71+3  66+3  57+3  57+3  57+3  66+3
# 2    76+3  77+3  77+3  77+3  76+3  74+3  72+3  72+3  72+3  74+3
# 3    63+3  58+3  58+3  58+3  63+3  58+3  44+3  44+3  44+3  58+3
# 4    73+3  77+3  77+3  77+3  73+3  76+3  85+3  85+3  85+3  76+3
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 995  57+2  56+2  56+2  56+2  57+2  55+2  53+2  53+2  53+2  55+2
# 996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 997  54+2  58+2  58+2  58+2  54+2  51+2  54+2  54+2  54+2  51+2
# 998  57+2  54+2  54+2  54+2  57+2  53+2  44+2  44+2  44+2  53+2
# 999  57+2  55+2  55+2  55+2  57+2  54+2  48+2  48+2  48+2  54+2
#
# [1000 rows x 92 columns]

# %% [markdown]
# # 2. Limpieza de datos

# %%
df.shape
# Out:
# (17954, 92)

# %%
#se eliminan columnas irrelavantes

df = df.drop(columns = ['national_team','national_rating','full_name','positions','potential','sliding_tackle','birth_date','preferred_foot', 'international_reputation(1-5)','weak_foot(1-5)','skill_moves(1-5)','work_rate','body_type','release_clause_euro','club_rating','club_position','club_jersey_number','national_team_position','national_jersey_number','crossing','finishing','heading_accuracy','short_passing','volleys','dribbling','curve','freekick_accuracy','long_passing','ball_control','acceleration','sprint_speed','agility','reactions','balance','shot_power','jumping','stamina','strength','long_shots','aggression','interceptions','positioning','vision','penalties','composure','marking','standing_tackle','GK_diving','GK_handling','GK_kicking','GK_positioning','GK_reflexes','tags','traits','LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB']) 
df.head(1000)
# Out:
#          id             name  age  height_cm  weight_kgs    nationality  \
# 0    158023         L. Messi   31     170.18        72.1      Argentina
# 1    190460       C. Eriksen   27     154.94        76.2        Denmark
# 2    195864         P. Pogba   25     190.50        83.9         France
# 3    198219       L. Insigne   27     162.56        59.0          Italy
# 4    201024     K. Koulibaly   27     187.96        88.9        Senegal
# ..      ...              ...  ...        ...         ...            ...
# 995  164478         C. Obasi   32     187.96        78.9        Nigeria
# 996   16254        T. Howard   40     190.50        88.0  United States
# 997  168317        H. Goitom   34     187.96        84.8        Eritrea
# 998  220029        S. Khaoui   23     182.88        68.0        Tunisia
# 999  188540  R. van La Parra   27     154.94        72.1    Netherlands
#
#      overall_rating   value_euro  wage_euro            club_team  \
# 0                94  110500000.0   565000.0         FC Barcelona
# 1                88   69500000.0   205000.0    Tottenham Hotspur
# 2                88   73000000.0   255000.0    Manchester United
# 3                88   62000000.0   165000.0               Napoli
# 4                88   60000000.0   135000.0               Napoli
# ..              ...          ...        ...                  ...
# 995              72    2500000.0     8000.0                  AIK
# 996              72     210000.0     3000.0      Colorado Rapids
# 997              72    2000000.0     8000.0                  AIK
# 998              72    4100000.0    25000.0  Stade Malherbe Caen
# 999              72    3300000.0    31000.0        Middlesbrough
#
#     club_join_date contract_end_year
# 0       01/07/2004              2021
# 1       30/08/2013              2020
# 2       09/08/2016              2021
# 3       01/07/2010              2022
# 4       01/07/2014              2021
# ..             ...               ...
# 995     22/01/2019              2019
# 996     04/07/2016              2019
# 997     07/03/2017              2019
# 998            NaN      Jun 30, 2019
# 999            NaN      Jun 30, 2019
#
# [1000 rows x 12 columns]

# %%
df.shape
# Out:
# (17954, 12)

# %%
df.isna().sum()
# Out:
# id                      0
# name                    0
# age                     0
# height_cm               0
# weight_kgs              0
# nationality             0
# overall_rating          0
# value_euro            255
# wage_euro             246
# club_team              14
# club_join_date       1936
# contract_end_year     361
# dtype: int64

# %%
#Eliminasmos las filas con NaN para lo columna de club_join_date (fecha de ingreso al club)
df = df[df['club_join_date'].notna()]

# %%
df.shape
# Out:
# (16018, 12)

# %%
df.isna().sum()
# Out:
# id                   0
# name                 0
# age                  0
# height_cm            0
# weight_kgs           0
# nationality          0
# overall_rating       0
# value_euro           9
# wage_euro            0
# club_team            0
# club_join_date       0
# contract_end_year    0
# dtype: int64

# %%
#Eliminasmos las filas con NaN para lo columna de value_euro (valor del jugador en euros)
df = df[df['value_euro'].notna()]

# %%
df.shape
# Out:
# (16009, 12)

# %%
valor_tabla = df['value_euro']
valor_tabla
# Out:
# 0        110500000.0
# 1         69500000.0
# 2         73000000.0
# 3         62000000.0
# 4         60000000.0
#             ...
# 17949       975000.0
# 17950       190000.0
# 17951       170000.0
# 17952       280000.0
# 17953       325000.0
# Name: value_euro, Length: 16009, dtype: float64

# %%
fechaContratacion_tabla = df['club_join_date']
fechaContratacion_tabla
# Out:
# 0        01/07/2004
# 1        30/08/2013
# 2        09/08/2016
# 3        01/07/2010
# 4        01/07/2014
#             ...
# 17949    01/01/2010
# 17950    07/07/2017
# 17951    01/07/2016
# 17952    12/08/2017
# 17953    31/01/2019
# Name: club_join_date, Length: 16009, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 3.Analisis de datos

# %%
df.club_join_date.unique()
# Out:
# array(['01/07/2004', '30/08/2013', '09/08/2016', ..., '01/08/2005',
#        '14/07/2010', '04/08/2010'], dtype=object)

# %%
df.value_euro.unique()
# Out:
# array([1.105e+08, 6.950e+07, 7.300e+07, 6.200e+07, 6.000e+07, 5.950e+07,
#        8.100e+07, 6.450e+07, 3.800e+07, 5.150e+07, 5.350e+07, 5.800e+07,
#        7.800e+07, 7.850e+07, 8.900e+07, 2.050e+07, 4.650e+07, 3.400e+07,
#        4.500e+07, 3.650e+07, 4.400e+07, 5.200e+07, 3.050e+07, 6.250e+07,
#        5.050e+07, 3.100e+07, 4.250e+07, 4.000e+07, 4.050e+07, 4.150e+07,
#        4.600e+07, 1.850e+07, 1.400e+07, 3.000e+07, 2.600e+07, 2.700e+07,
#        2.250e+07, 2.800e+07, 3.300e+07, 2.950e+07, 3.450e+07, 3.550e+07,
#        2.500e+07, 2.150e+07, 3.150e+07, 2.900e+07, 3.200e+07, 6.500e+06,
#        1.650e+07, 3.250e+07, 9.000e+06, 1.800e+07, 2.100e+07, 2.200e+07,
#        2.300e+07, 2.350e+07, 1.700e+07, 2.000e+07, 1.950e+07, 1.450e+07,
#        1.550e+07, 4.500e+06, 1.050e+07, 6.000e+06, 5.500e+06, 1.500e+07,
#        1.300e+07, 1.150e+07, 1.600e+07, 8.500e+06, 1.000e+06, 1.200e+07,
#        7.000e+06, 9.500e+06, 2.000e+06, 1.750e+07, 1.000e+07, 1.350e+07,
#        8.000e+06, 1.250e+07, 4.000e+06, 5.000e+06, 1.100e+07, 3.000e+06,
#        7.500e+06, 3.600e+06, 3.200e+06, 4.700e+06, 2.700e+06, 2.100e+06,
#        3.100e+06, 1.800e+06, 3.400e+06, 2.300e+06, 4.800e+06, 4.400e+06,
#        3.900e+06, 3.700e+06, 1.600e+06, 1.900e+06, 2.900e+06, 3.800e+06,
#        4.500e+05, 1.700e+06, 4.200e+06, 2.800e+06, 4.900e+06, 4.600e+06,
#        1.300e+06, 2.200e+06, 4.100e+06, 3.500e+06, 4.300e+06, 1.200e+06,
#        2.700e+05, 2.600e+06, 5.500e+05, 3.300e+06, 2.400e+06, 2.500e+06,
#        1.100e+06, 9.500e+05, 4.250e+05, 9.000e+05, 1.400e+06, 2.100e+05,
#        8.750e+05, 1.500e+06, 7.500e+05, 1.600e+05, 8.500e+05, 6.750e+05,
#        6.000e+05, 8.250e+05, 7.250e+05, 9.250e+05, 5.000e+05, 2.400e+05,
#        1.200e+05, 2.500e+05, 5.250e+05, 7.750e+05, 9.750e+05, 7.000e+05,
#        3.750e+05, 5.750e+05, 7.000e+04, 6.500e+05, 4.750e+05, 3.250e+05,
#        6.250e+05, 8.000e+05, 3.500e+05, 6.000e+04, 2.600e+05, 2.300e+05,
#        3.000e+05, 5.000e+04, 1.000e+05, 1.800e+05, 4.000e+05, 2.200e+05,
#        1.500e+05, 1.400e+05, 2.000e+05, 4.000e+04, 9.000e+04, 2.800e+05,
#        1.300e+05, 1.700e+05, 3.000e+04, 1.900e+05, 1.100e+05, 2.900e+05,
#        2.000e+04, 1.000e+04, 8.000e+04, 1.900e+07, 2.450e+07, 2.400e+07,
#        2.650e+07, 2.750e+07, 2.850e+07, 2.550e+07, 4.100e+07, 3.350e+07,
#        3.750e+07, 3.700e+07, 3.900e+07, 4.350e+07, 4.300e+07, 3.500e+07,
#        5.500e+07, 5.000e+07, 5.300e+07, 6.100e+07, 5.700e+07, 3.600e+07,
#        5.900e+07, 6.300e+07, 7.650e+07, 7.700e+07, 6.800e+07, 9.650e+07,
#        8.000e+07, 6.700e+07, 9.300e+07, 1.020e+08, 7.200e+07, 1.080e+08])

# %%
gender_frame = pd.DataFrame(data=df['value_euro'])
gender_frame 
x=max(valor_tabla)
y=min(valor_tabla)
z= df["value_euro"].mean()
w=df["value_euro"].median()
m = df["value_euro"].mode()
r=df["value_euro"].count()
s=df["value_euro"].sum()
k=df["value_euro"].kurtosis()
v=df["value_euro"].var()
d=df["value_euro"].std()
print("Max {0}\n Min {1}\n Promedio {2}\n Mediana {3}\n moda {4}\n Conteo {5}\n Suma {6}\n Kutosis {7}\n Varianza {8}\n Desviacion Estandar {9}\n".format(x,y,z,w,m,r,s,k,v,d))
# Out:
# Max 110500000.0
#  Min 10000.0
#  Promedio 2437092.2606034107
#  Mediana 675000.0
#  moda 0    425000.0
# dtype: float64
#  Conteo 16009
#  Suma 39015410000.0
#  Kutosis 73.1784493508142
#  Varianza 33742800371360.082
#  Desviacion Estandar 5808855.340887745

# %%
g = df.groupby(['club_join_date','value_euro', 'name']).mean()
g
# Out:
#                                                  id   age  height_cm  \
# club_join_date value_euro name
# 01/01/1998     60000.0    H. Sogahata      140181.0  39.0     187.96
# 01/01/2002     20000.0    Y. Kurihara      217645.0  35.0     182.88
#                250000.0   Kim Kwang Suk    184900.0  36.0     182.88
#                8500000.0  I. Akinfeev      148119.0  32.0     185.42
# 01/01/2003     20000.0    M. McNulty       142333.0  38.0     187.96
# ...                                             ...   ...        ...
# 31/12/2018     40000.0    Ahn Byeong Geon  247591.0  30.0     187.96
#                110000.0   A. Reardon       246707.0  19.0     154.94
#                130000.0   B. Michel        247354.0  21.0     152.40
#                725000.0   Caíque           247287.0  25.0     185.42
#                875000.0   I. Camará        247288.0  20.0     190.50
#
#                                            weight_kgs  overall_rating  \
# club_join_date value_euro name
# 01/01/1998     60000.0    H. Sogahata            79.8            68.0
# 01/01/2002     20000.0    Y. Kurihara            79.8            53.0
#                250000.0   Kim Kwang Suk          73.0            69.0
#                8500000.0  I. Akinfeev            78.0            80.0
# 01/01/2003     20000.0    M. McNulty             69.9            62.0
# ...                                               ...             ...
# 31/12/2018     40000.0    Ahn Byeong Geon        81.2            52.0
#                110000.0   A. Reardon             74.8            54.0
#                130000.0   B. Michel              74.8            53.0
#                725000.0   Caíque                 74.8            65.0
#                875000.0   I. Camará              78.0            66.0
#
#                                            wage_euro
# club_join_date value_euro name
# 01/01/1998     60000.0    H. Sogahata         3000.0
# 01/01/2002     20000.0    Y. Kurihara         1000.0
#                250000.0   Kim Kwang Suk       3000.0
#                8500000.0  I. Akinfeev         1000.0
# 01/01/2003     20000.0    M. McNulty          1000.0
# ...                                              ...
# 31/12/2018     40000.0    Ahn Byeong Geon     1000.0
#                110000.0   A. Reardon          1000.0
#                130000.0   B. Michel           1000.0
#                725000.0   Caíque              3000.0
#                875000.0   I. Camará           1000.0
#
# [16008 rows x 6 columns]

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16009 entries, 0 to 17953
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 16009 non-null  int64
#  1   name               16009 non-null  object
#  2   age                16009 non-null  int64
#  3   height_cm          16009 non-null  float64
#  4   weight_kgs         16009 non-null  float64
#  5   nationality        16009 non-null  object
#  6   overall_rating     16009 non-null  int64
#  7   value_euro         16009 non-null  float64
#  8   wage_euro          16009 non-null  float64
#  9   club_team          16009 non-null  object
#  10  club_join_date     16009 non-null  object
#  11  contract_end_year  16009 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# #4. Graficación

# %%
plt.plot(df['overall_rating'], df['value_euro'], label='value_euro')


plt.xlabel('Calificación del jugador')
plt.ylabel('Valor del jugador en euros')
plt.title('Calificación-valor')
plt.grid(True)

# %%
plt.bar(df['overall_rating'], df['value_euro'], width=20)
# Out:
# <BarContainer object of 16009 artists>

# %%
nacionalidades_tabla = df['nationality']
nacionalidades_tabla
# Out:
# 0           Argentina
# 1             Denmark
# 2              France
# 3               Italy
# 4             Senegal
#              ...
# 17949        Scotland
# 17950        Slovakia
# 17951     Netherlands
# 17952    Saudi Arabia
# 17953          Brazil
# Name: nationality, Length: 16009, dtype: object

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=df['nationality'], y=df['value_euro']))

fig.update_layout(
    xaxis=dict(
        title_text='nationality',
        titlefont=dict(size=30),
    ),
    yaxis=dict(
        title_text='value_euro',
        
        titlefont=dict(size=30)
    ),
    title="Nacionalidades de jugadores con mas Ranking(Con mas valor)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="42e92cb2-6219-46a7-99ff-e81c6e8bd5ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42e92cb2-6219-46a7-99ff-e81c6e8bd5ef")) {                    Plotly.newPlot(                        "42e92cb2-6219-46a7-99ff-e81c6e8bd5ef",                        [{"x":["Argentina","Denmark","France","Italy","Senegal","Netherlands","France","Argentina","Germany","Uruguay","Spain","Belgium","Germany","France","Egypt","Argentina","Slovakia","Brazil","Croatia","Belgium","Belgium","Brazil","Belgium","Spain","Spain","Italy","Costa Rica","Spain","Brazil","Argentina","Spain","Morocco","Brazil","France","Germany","Germany","Brazil","Uruguay","France","Colombia","Spain","France","Spain","Sweden","Italy","Bosnia Herzegovina","Germany","Portugal","Brazil","Spain","Netherlands","Germany","France","Italy","Portugal","Brazil","France","France","Germany","France","Spain","Mexico","Brazil","Uruguay","Portugal","Spain","Netherlands","Brazil","Brazil","Brazil","Brazil","Spain","Italy","Germany","England","Argentina","Austria","Iceland","Brazil","Hungary","Brazil","England","Wales","Italy","Ukraine","Brazil","Italy","Central African Rep.","France","Germany","France","Austria","Serbia","France","Germany","Spain","France","Portugal","Portugal","Spain","Germany","Ivory Coast","Netherlands","Cameroon","Paraguay","Spain","Brazil","Brazil","Brazil","Spain","Spain","France","France","Uruguay","Spain","France","Cameroon","Ivory Coast","France","England","Australia","Croatia","Spain","Spain","Brazil","Algeria","Romania","England","England","Italy","England","Spain","Argentina","Argentina","Brazil","Spain","Spain","Russia","Russia","France","Portugal","Brazil","France","Spain","Belgium","Germany","Israel","Spain","Morocco","Germany","Brazil","Spain","Russia","Portugal","Brazil","Colombia","Ivory Coast","Argentina","Argentina","Switzerland","Iceland","Brazil","Spain","Spain","Spain","Spain","Chile","Morocco","Spain","Spain","Tunisia","England","Iceland","Brazil","Spain","Turkey","Spain","Germany","Turkey","Germany","England","Netherlands","France","Ivory Coast","Argentina","France","England","England","Brazil","England","Nigeria","England","Russia","Colombia","Argentina","Argentina","Serbia","Serbia","Spain","Brazil","Slovakia","Germany","France","England","Germany","Ukraine","Portugal","France","Germany","Brazil","France","Germany","Spain","Germany","Norway","Greece","Spain","France","England","Spain","Mexico","Germany","Spain","Peru","Bosnia Herzegovina","Austria","Spain","Austria","France","Chile","Spain","United States","Spain","Uruguay","Cameroon","Austria","England","France","Spain","England","England","England","Brazil","Netherlands","Brazil","Bosnia Herzegovina","Argentina","Brazil","Argentina","Iran","Serbia","Spain","Egypt","Spain","Portugal","Spain","Colombia","Ukraine","Spain","Italy","Belgium","Germany","Equatorial Guinea","Brazil","Cape Verde","Spain","Germany","Denmark","Turkey","Nigeria","Tunisia","Germany","Argentina","Italy","Argentina","Germany","Netherlands","Argentina","Spain","Greece","Argentina","Slovakia","England","Italy","Sweden","Colombia","Portugal","Belgium","Spain","Colombia","Portugal","Italy","France","Spain","Tanzania","France","England","Spain","Netherlands","Switzerland","Portugal","Spain","Switzerland","Ivory Coast","Portugal","Spain","Denmark","Germany","Scotland","China PR","Argentina","Croatia","Argentina","Italy","Belgium","Kosovo","England","England","Italy","Ukraine","Portugal","Scotland","Brazil","Italy","Montenegro","Canada","Argentina","England","Brazil","Brazil","Italy","Brazil","Madagascar","Spain","Turkey","Italy","Brazil","Spain","United States","France","Spain","Netherlands","Brazil","Mali","Italy","Croatia","Algeria","Spain","Fra ...

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=df['nationality'], y=df['wage_euro']))

fig.update_layout(
    xaxis=dict(
        title_text='nationality',
        titlefont=dict(size=30),
    ),
    yaxis=dict(
        title_text="wage_euro",
        
        titlefont=dict(size=30)
    ),
    title="Nacionalidades de jugadores que mas ganan en Euros $"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2b2b17ef-5d76-4d85-a401-54c0f3de8e67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b2b17ef-5d76-4d85-a401-54c0f3de8e67")) {                    Plotly.newPlot(                        "2b2b17ef-5d76-4d85-a401-54c0f3de8e67",                        [{"x":["Argentina","Denmark","France","Italy","Senegal","Netherlands","France","Argentina","Germany","Uruguay","Spain","Belgium","Germany","France","Egypt","Argentina","Slovakia","Brazil","Croatia","Belgium","Belgium","Brazil","Belgium","Spain","Spain","Italy","Costa Rica","Spain","Brazil","Argentina","Spain","Morocco","Brazil","France","Germany","Germany","Brazil","Uruguay","France","Colombia","Spain","France","Spain","Sweden","Italy","Bosnia Herzegovina","Germany","Portugal","Brazil","Spain","Netherlands","Germany","France","Italy","Portugal","Brazil","France","France","Germany","France","Spain","Mexico","Brazil","Uruguay","Portugal","Spain","Netherlands","Brazil","Brazil","Brazil","Brazil","Spain","Italy","Germany","England","Argentina","Austria","Iceland","Brazil","Hungary","Brazil","England","Wales","Italy","Ukraine","Brazil","Italy","Central African Rep.","France","Germany","France","Austria","Serbia","France","Germany","Spain","France","Portugal","Portugal","Spain","Germany","Ivory Coast","Netherlands","Cameroon","Paraguay","Spain","Brazil","Brazil","Brazil","Spain","Spain","France","France","Uruguay","Spain","France","Cameroon","Ivory Coast","France","England","Australia","Croatia","Spain","Spain","Brazil","Algeria","Romania","England","England","Italy","England","Spain","Argentina","Argentina","Brazil","Spain","Spain","Russia","Russia","France","Portugal","Brazil","France","Spain","Belgium","Germany","Israel","Spain","Morocco","Germany","Brazil","Spain","Russia","Portugal","Brazil","Colombia","Ivory Coast","Argentina","Argentina","Switzerland","Iceland","Brazil","Spain","Spain","Spain","Spain","Chile","Morocco","Spain","Spain","Tunisia","England","Iceland","Brazil","Spain","Turkey","Spain","Germany","Turkey","Germany","England","Netherlands","France","Ivory Coast","Argentina","France","England","England","Brazil","England","Nigeria","England","Russia","Colombia","Argentina","Argentina","Serbia","Serbia","Spain","Brazil","Slovakia","Germany","France","England","Germany","Ukraine","Portugal","France","Germany","Brazil","France","Germany","Spain","Germany","Norway","Greece","Spain","France","England","Spain","Mexico","Germany","Spain","Peru","Bosnia Herzegovina","Austria","Spain","Austria","France","Chile","Spain","United States","Spain","Uruguay","Cameroon","Austria","England","France","Spain","England","England","England","Brazil","Netherlands","Brazil","Bosnia Herzegovina","Argentina","Brazil","Argentina","Iran","Serbia","Spain","Egypt","Spain","Portugal","Spain","Colombia","Ukraine","Spain","Italy","Belgium","Germany","Equatorial Guinea","Brazil","Cape Verde","Spain","Germany","Denmark","Turkey","Nigeria","Tunisia","Germany","Argentina","Italy","Argentina","Germany","Netherlands","Argentina","Spain","Greece","Argentina","Slovakia","England","Italy","Sweden","Colombia","Portugal","Belgium","Spain","Colombia","Portugal","Italy","France","Spain","Tanzania","France","England","Spain","Netherlands","Switzerland","Portugal","Spain","Switzerland","Ivory Coast","Portugal","Spain","Denmark","Germany","Scotland","China PR","Argentina","Croatia","Argentina","Italy","Belgium","Kosovo","England","England","Italy","Ukraine","Portugal","Scotland","Brazil","Italy","Montenegro","Canada","Argentina","England","Brazil","Brazil","Italy","Brazil","Madagascar","Spain","Turkey","Italy","Brazil","Spain","United States","France","Spain","Netherlands","Brazil","Mali","Italy","Croatia","Algeria","Spain","Fra ...

# %%
sns.pairplot(   , hue='overall_rating')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-e0612caad6d7> in <module>()
# ----> 1 sns.pairplot(hue='overall_rating')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: pairplot() missing 1 required positional argument: 'data'
